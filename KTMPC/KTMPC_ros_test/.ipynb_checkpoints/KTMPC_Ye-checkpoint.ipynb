# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np
from numpy.random import rand,uniform
from nonlinear_model import discrete_nonlinear
from Koopman_numpy import Koopman_numpy
import matplotlib.pyplot as plt
from MPC import *
import time

# %%
# Yiping's models
# model_name = 'newnew_unmasked_encoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 3.0, 0.3, 1e-07, 1e-07, 1e-07, 10]_batch_10'
model_name = 'unmasked_encoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 3.0, 0.3, 1e-07, 1e-07, 1e-07, 10]_batch_10'

Ts = 0.1
operator = Koopman_numpy(model_name)
A,B = operator.linear_matrix()

x_range = np.array([2.,2.,np.pi])
u_range = np.array([1.5,0.5])

# x_range = np.array([1.,1.,2*np.pi])
# u_range = np.array([0.4,0.3])

x = np.array([0,0,0])
u = np.array([0.5,0])

z = operator.encode(x)
xK = operator.decode(z)

x = np.vstack((x,discrete_nonlinear(x,u,Ts)))
z = np.vstack((z,operator.linear(z,u)))
xK = np.vstack((xK,operator.decode(z[1])))

print(x[1])
print(xK[1])
# Out:
# [0.05 0.   0.  ]
# [ 0.04195225 -0.01901657 -0.03625519]

# %%
# Test Koopman model for AGV dynamics

operator = Koopman_numpy(model_name)
A,B = operator.linear_matrix()
# print(A)

# Ts = 0.1
x_range = np.array([2.,2.,np.pi])
u_range = np.array([1.5,0.5])

# x = np.array([.1,.1,0.3])
# x = np.array([0,0,0])
# x = np.random.uniform(low=-x_range,high=x_range,size=(1,3)).squeeze()
# u = np.array([0.5,0.3])
x = np.array([0,0,0])
u = np.array([0.5,0])

z = operator.encode(x)
xK = operator.decode(z)

x = np.vstack((x,discrete_nonlinear(x,u,Ts)))
z = np.vstack((z,operator.linear(z,u)))
xK = np.vstack((xK,operator.decode(z[1])))

simtime = 10
uk = u

for i in range(1,simtime):
    # Koopman model
    uk = np.random.uniform(low=-u_range,high=u_range,size=(1,2)).squeeze()
    # uk = np.array([0.5,0.3])
    # uk[1] = -0.2

    # print(uk)
    z1 = operator.linear(z[i],uk)
    z = np.vstack((z,z1))
    xK = np.vstack((xK,operator.decode(z1)))

    # Nonlinear model
    x1 = discrete_nonlinear(x[i],uk,Ts)
    x = np.vstack((x,x1))

# %%
# Plot comparison results
plt.figure()
ax1=plt.subplot(221)
plt.plot(xK[:,0],color='tab:blue', marker='o')
# plt.plot(z[:,0],color='green')
plt.plot(x[:,0],color='black')
ax1.set_title('x')
plt.legend(['Koopman-x','Nonlinear'])

ax2=plt.subplot(222)
plt.plot(xK[:,1],color='tab:blue', marker='o')
# plt.plot(z[:,1],color='green')
plt.plot(x[:,1],color='black')
ax2.set_title('y')

ax3=plt.subplot(223)
plt.plot(xK[:,2],color='tab:blue', marker='o')
# plt.plot(z[:,2],color='green')
plt.plot(x[:,2],color='black')
ax3.set_title('theta')

ax3=plt.subplot(224)
plt.plot(xK[:,0],xK[:,1],color='tab:blue', marker='o')
# plt.plot(z[:,2],color='green')
plt.plot(x[:,0],x[:,1],color='black')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Data-driven Tracking MPC using Koopman Operators

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np
from numpy.random import rand,uniform
from nonlinear_model import discrete_nonlinear
from Koopman_numpy import Koopman_numpy
import matplotlib.pyplot as plt
from MPC import *
import time

# Koopman model
# model_name = 'encoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 3.0, 0.3, 1e-07, 1e-07, 1e-07, 3.0, 10]_batch_10'
# model_name = 'newencoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 3.0, 0.3, 1e-07, 1e-07, 1e-07, 3.0, 10]_batch_10'
# model_name = 'encoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 3.0, 0.3, 1e-07, 1e-07, 1e-07, 8.0, 10]_batch_10'
model_name = 'unmasked_encoder_[3, 32, 64, 8]_decoder_[11, 128, 64, 32, 3]_hyper_[1.0, 3.0, 0.3, 1e-07, 1e-07, 1e-07, 10]_batch_10'

Ts = 0.1
operator = Koopman_numpy(model_name)

# Simulation Parameters
init_state = np.array([0.,0.,0.])
# init_state = np.array([-0.02102801, -0.02277652, -0.02808019])
# yt = np.array([[0.5,0.,0.],[1.,0.5,0.],[2,0.5,0.],[4.,-0.5,0.],[5.,0.,0.]])
# yt = np.array([[1.,0.5,np.pi/4],[2.,0.5,0.],[4.,-0.5,0.],[5.,0.,0.]])
# yt = np.array([[1.,0.,0.],[1.1,0.1,-np.pi/4],[2.,-1.,-np.pi/4],[2.1,-1.1,-np.pi/8],[7.,0.,0.]])

# yt = np.array([[1.,0.,0.],[1.,0.,-np.pi/5],[2.,-0.8,-np.pi/4],[2.4,-1.2,-np.pi/8],[2.4,-1.2,0.],
#                [2.4,-1.2,np.pi/6],[2.8,-0.7,np.pi/4]])
# yt = np.array([[1.,0.,0.],[1.,0.,np.pi/6],[2.,0.8,np.pi/4],[2.4,1.2,np.pi/8],[2.4,1.2,0.],
#                [2.4,1.2,-np.pi/8],[3,0.7,-np.pi/6],[4,0,-np.pi/3]])
yt = np.array([[-1.0,0.,0.],[1.,0.,0.],[1.,0.,np.pi/6],[2.,0.8,np.pi/4],[2.4,1.2,np.pi/8],[2.4,1.2,0.],
               [2.4,1.2,-np.pi/7],[3,0.8,-np.pi/5],[3.8,0.1,-np.pi/3],[3.9,0.,-np.pi/4]])
# yt = np.array([[-1.,0.,0.]])
changedt = 20
simtime = changedt*yt.shape[0]

Ts = 0.1
x_range = np.array([2.,2.,np.pi])
u_range = np.array([1.5,0.5])

# x_range = np.array([1.,1.,2*np.pi])
# u_range = np.array([0.4,0.3])

# Weights
# q = 50 # for x
q = 10*np.array([10,10,10,10,10,10,10,10,10,10,10])
# q = 10*np.array([20,30,10,10,30,10,20,10,10,20,10])
r = 0.01*np.array([2,1]) # for u
s = 100*np.array([10,10,10,10,10,10,10,10,10,10,10]) # for offset function
# s = 100*np.array([20,30,10,10,30,10,20,10,10,20,10])

# Prediction horizon
N = 10

# Simulation Loop
model_flag = "nonlinear"
x,z,u,zr,yr,zs,ys,us = KTMPC_simulation(model_name,yt,init_state,x_range,u_range,q,r,s,N,simtime,changedt,model_flag)
# Out:
# Simulation in progress:
#   0%|          | 0/200 [00:00<?, ?it/s]/Users/yewang2/.conda/envs/Koopman/lib/python3.9/site-packages/cvxpy/problems/problem.py:1333: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# 100%|██████████| 200/200 [00:28<00:00,  6.90it/s]
# Simulation Done!

# %%
# Plot simulation results
KTMPC_simulation_plot(x,z,u,yt,zr,yr,ys,us,u_range,simtime,Ts)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# Plot analysis results - lifted space
KTMPC_analysis_z_plot(x,z,u,yt,zr,yr,zs,ys,simtime,Ts)
# Out:
# <img src="data:image/png;base64,..." width="640">
